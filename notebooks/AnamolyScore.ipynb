# %%
import pandas as pd

ae_df = pd.read_csv("/content/fraud_with_rules_and_ae.csv")
iso_df = pd.read_csv("/content/fraud_final_with_Iso_score.csv")

# %%
iso_df.shape
# Out:
# (144233, 615)

# %%
ae_df.shape
# Out:
# (144233, 617)

# %%
ae_df['iso_score'] = iso_df['iso_score']

# %%
ae_df.shape
# Out:
# (144233, 618)

# %%
ae_df.to_csv("final_combined_anamoly_scores.csv", index=False)
